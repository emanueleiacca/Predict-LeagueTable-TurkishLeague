# %% [markdown]
# Env is Basic.py

# %%
import pandas as pd

# Load the Excel file to check its contents
file_path = '20_21_season.xlsx'
excel_data = pd.ExcelFile(file_path)

# Display sheet names to understand the structure of the file
sheet_names = excel_data.sheet_names
sheet_names
# Out:
# ['Players', 'Teams', 'Rank_outcomes']

# %%
players_data = pd.read_excel(file_path, sheet_name='Players')
teams_data = pd.read_excel(file_path, sheet_name='Teams')
rank_outcomes_data = pd.read_excel(file_path, sheet_name='Rank_outcomes')

# Display the first few rows of each sheet to understand their structure
players_data_head = players_data.head()
teams_data_head = teams_data.head()
rank_outcomes_data_head = rank_outcomes_data.head()

(players_data_head, teams_data_head, rank_outcomes_data_head)
# Out:
# (        LAST NAME                            MATCH MATCH DATE        TEAM  \
#  0  Bayindir Altay          Rizespor 1:2 Fenerbahce   11.09.20  Fenerbahce
#  1  Bayindir Altay         Fenerbahce 0:0 Hatayspor   21.09.20  Fenerbahce
#  2  Bayindir Altay  Fenerbahce 2:1 Fatih Karagumruk   03.10.20  Fenerbahce
#  3  Bayindir Altay           Goztepe 2:3 Fenerbahce   18.10.20  Fenerbahce
#  4  Bayindir Altay       Fenerbahce 3:1 Trabzonspor   25.10.20  Fenerbahce
#
#     MINS PLAYED  DISTANCE COVERED - TOTAL DISTANCE  \
#  0         98.0                             5457.0
#  1         98.0                             5147.0
#  2         97.0                             5311.0
#  3        101.0                             5472.0
#  4         97.0                             5403.0
#
#     DISTANCE COVERED - DISTANCE ON SPEED UP TO 0,2 M/S  \
#  0                                               49.0
#  1                                               73.0
# ...

# %% [markdown]
# Player Data

# %%
players_data.columns.tolist()
# Out:
# ['LAST NAME',
#  'MATCH',
#  'MATCH DATE',
#  'TEAM',
#  'MINS PLAYED',
#  'DISTANCE COVERED - TOTAL DISTANCE',
#  'DISTANCE COVERED - DISTANCE ON SPEED UP TO 0,2 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 0,21 - 2 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 2,01 - 4 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 4,01 - 5,5 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 5,51 - 7 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED OVER 7 M/S',
#  'DISTANCE COVERED - NO. OF ACCELERATIONS (5,5 - 7)',
#  'DISTANCE COVERED - NO. OF ACCELERATIONS (>7)',
#  'DISTANCE COVERED - MAXIMAL SPEED',
#  'NUMBER OF HIGH SPEED RUNS ATTACKING',
#  'NUMBER OF HIGH SPEED RUNS DEFENSIVE',
#  'NUMBER OF SPRINTS ATTACKING',
#  'NUMBER OF SPRINTS DEFENSIVE']

# %%
players_data.columns = [
    'Last Name', 'Match', 'Match Date', 'Team', 'Minutes Played', 
    'Total Distance Covered', 'Distance Covered Speed 0-0.2 m/s', 
    'Distance Covered Speed 0.21-2 m/s', 'Distance Covered Speed 2.01-4 m/s', 
    'Distance Covered Speed 4.01-5.5 m/s', 'Distance Covered Speed 5.51-7 m/s', 
    'Distance Covered Speed >7 m/s', 'No. of Accelerations 5.5-7 m/s²', 
    'No. of Accelerations >7 m/s²', 'Maximal Speed', 
    'High Speed Runs Attacking', 'High Speed Runs Defensive', 
    'Sprints Attacking', 'Sprints Defensive'
]

# %%
# Check for missing values
missing_values_players = players_data.isnull().sum()

# Display the updated columns and the missing values
missing_values_players
# Out:
# Last Name                              0
# Match                                  0
# Match Date                             0
# Team                                   0
# Minutes Played                         0
# Total Distance Covered                 0
# Distance Covered Speed 0-0.2 m/s       0
# Distance Covered Speed 0.21-2 m/s      0
# Distance Covered Speed 2.01-4 m/s      0
# Distance Covered Speed 4.01-5.5 m/s    0
# Distance Covered Speed 5.51-7 m/s      0
# Distance Covered Speed >7 m/s          0
# No. of Accelerations 5.5-7 m/s²        0
# No. of Accelerations >7 m/s²           0
# Maximal Speed                          0
# High Speed Runs Attacking              0
# High Speed Runs Defensive              0
# Sprints Attacking                      0
# Sprints Defensive                      0
# dtype: int64

# %%
teams_data.columns.tolist()
# Out:
# ['TEAM',
#  'MATCH',
#  'MATCH DATE',
#  'DISTANCE COVERED - TOTAL DISTANCE',
#  'DISTANCE COVERED - DISTANCE ON SPEED UP TO 0,2 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 0,21 - 2 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 2,01 - 4 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 4,01 - 5,5 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED 5,51 - 7 M/S',
#  'DISTANCE COVERED - DISTANCE ON SPEED OVER 7 M/S',
#  'DISTANCE COVERED - NO. OF ACCELERATIONS (5,5 - 7)',
#  'DISTANCE COVERED - NO. OF ACCELERATIONS (>7)',
#  'DISTANCE COVERED - MAXIMAL SPEED']

# %%
teams_data.columns = [
    'Team', 'Match', 'Match Date', 'Total Distance Covered', 
    'Distance Covered Speed 0-0.2 m/s', 'Distance Covered Speed 0.21-2 m/s', 
    'Distance Covered Speed 2.01-4 m/s', 'Distance Covered Speed 4.01-5.5 m/s', 
    'Distance Covered Speed 5.51-7 m/s', 'Distance Covered Speed >7 m/s', 
    'No. of Accelerations 5.5-7 m/s²', 'No. of Accelerations >7 m/s²', 
    'Maximal Speed'
]

# %%
missing_values_teams = teams_data.isnull().sum()
missing_values_teams
# Out:
# Team                                   0
# Match                                  0
# Match Date                             0
# Total Distance Covered                 0
# Distance Covered Speed 0-0.2 m/s       0
# Distance Covered Speed 0.21-2 m/s      0
# Distance Covered Speed 2.01-4 m/s      0
# Distance Covered Speed 4.01-5.5 m/s    0
# Distance Covered Speed 5.51-7 m/s      0
# Distance Covered Speed >7 m/s          0
# No. of Accelerations 5.5-7 m/s²        0
# No. of Accelerations >7 m/s²           0
# Maximal Speed                          0
# dtype: int64

# %%
rank_outcomes_data.head()
# we need some cleaning
# Out:
#    Unnamed: 0 Unnamed: 1      Unnamed: 2 Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0         NaN        NaN             NaN        NaN          NaN         NaN
# 1         NaN      TEAMS  LATEST RESULTS          P          NaN         NaN
# 2         NaN        NaN               1        NaN     BESIKTAS         NaN
# 3         NaN        NaN               2        NaN  GALATASARAY         NaN
# 4         NaN        NaN               3        NaN   FENERBAHÇE         NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9   Unnamed: 10     Unnamed: 11  \
# 0        NaN       Wins      Draws       Lost  Goals scored  Goals suffered
# 1    Matches          W          D          L            GF              GA
# 2         40         26          6          8            89              44
# 3         40         26          6          8            80              36
# 4         40         25          7          8            72              41
#
#         Unnamed: 12 Unnamed: 13
# ...

# %%
# Rename columns for better readability
rank_outcomes_data.columns = [
    'Index', 'Teams Header', 'Rank', 'P Header', 'Team', 'NaN1', 'Matches', 
    'Wins', 'Draws', 'Losses', 'Goals Scored', 'Goals Conceded', 
    'Goal Difference', 'Points'
]

# Drop the first two rows which contain header information and NaN values
rank_outcomes_data = rank_outcomes_data.drop([0, 1])

# Drop unnecessary columns
rank_outcomes_data = rank_outcomes_data.drop(columns=['Index', 'Teams Header', 'P Header', 'NaN1'])

# Reset the index
rank_outcomes_data.reset_index(drop=True, inplace=True)



# Display the cleaned data
rank_outcomes_data
# Out:
#    Rank              Team Matches Wins Draws Losses Goals Scored  \
# 0     1          BESIKTAS      40   26     6      8           89
# 1     2       GALATASARAY      40   26     6      8           80
# 2     3        FENERBAHÇE      40   25     7      8           72
# 3     4       TRABZONSPOR      40   19    14      7           50
# 4     5         SIVASSPOR      40   16    17      7           54
# 5     6         HATAYSPOR      40   17    10     13           62
# 6     7        ALANYASPOR      40   17     9     14           58
# 7     8  FATIH KARAGÜMRÜK      40   16    12     12           64
# 8     9      GAZIANTEP FK      40   15    13     12           59
# 9    10           GÖZTEPE      40   13    12     15           59
# 10   11         KONYASPOR      40   12    14     14           49
# 11   12        BASAKSEHIR      40   12    12     16           43
# 12   13   ÇAYKUR RIZESPOR      40   12    12     16           53
# ...

# %%
missing_values_rank_outcomes = rank_outcomes_data.isnull().sum()
missing_values_rank_outcomes
# Out:
# Rank               0
# Team               0
# Matches            0
# Wins               0
# Draws              0
# Losses             0
# Goals Scored       0
# Goals Conceded     0
# Goal Difference    0
# Points             0
# dtype: int64

# %%
# List unique team names from both DataFrames
teams_unique = teams_data['Team'].unique()
rank_outcomes_unique = rank_outcomes_data['Team'].unique()

teams_unique, rank_outcomes_unique
# Out:
# (array(['Rizespor', 'Fenerbahce', 'Sivasspor', 'Alanyaspor',
#         'Fatih Karagumruk', 'Yeni Malatyaspor', 'Galatasaray',
#         'Gaziantep FK', 'Ankaragucu', 'BB Erzurumspor', 'Kayserispor',
#         'Kasimpasa', 'Trabzonspor', 'Besiktas', 'Antalyaspor',
#         'Genclerbirligi', 'Goztepe', 'Denizlispor', 'Istanbul Basaksehir',
#         'Hatayspor', 'Konyaspor'], dtype=object),
#  array(['BESIKTAS', 'GALATASARAY', 'FENERBAHÇE', 'TRABZONSPOR',
#         'SIVASSPOR', 'HATAYSPOR', 'ALANYASPOR', 'FATIH KARAGÜMRÜK',
#         'GAZIANTEP FK', 'GÖZTEPE', 'KONYASPOR', 'BASAKSEHIR',
#         'ÇAYKUR RIZESPOR', 'KASIMPASA', 'YENI MALATYASPOR', 'ANTALYASPOR',
#         'KAYSERISPOR', 'BB ERZURUMSPOR', 'MKE ANKARAGÜCÜ',
#         'GENÇLERBIRLIGI', 'DENIZLISPOR'], dtype=object))

# %% [markdown]
# Normalize Team Names

# %%
# Create a mapping dictionary to standardize team names
team_name_mapping = {
    'BESIKTAS': 'Besiktas',
    'GALATASARAY': 'Galatasaray',
    'FENERBAHÇE': 'Fenerbahce',
    'TRABZONSPOR': 'Trabzonspor',
    'SIVASSPOR': 'Sivasspor',
    'HATAYSPOR': 'Hatayspor',
    'ALANYASPOR': 'Alanyaspor',
    'FATIH KARAGÜMRÜK': 'Fatih Karagumruk',
    'GAZIANTEP FK': 'Gaziantep FK',
    'GÖZTEPE': 'Goztepe',
    'KONYASPOR': 'Konyaspor',
    'BASAKSEHIR': 'Istanbul Basaksehir',
    'ÇAYKUR RIZESPOR': 'Rizespor',
    'KASIMPASA': 'Kasimpasa',
    'YENI MALATYASPOR': 'Yeni Malatyaspor',
    'ANTALYASPOR': 'Antalyaspor',
    'KAYSERISPOR': 'Kayserispor',
    'BB ERZURUMSPOR': 'BB Erzurumspor',
    'MKE ANKARAGÜCÜ': 'Ankaragucu',
    'GENÇLERBIRLIGI': 'Genclerbirligi',
    'DENIZLISPOR': 'Denizlispor'
}

# Apply the mapping to the rank_outcomes_data
rank_outcomes_data['Team'] = rank_outcomes_data['Team'].map(team_name_mapping)

# Verify the updated team names in rank_outcomes_data
rank_outcomes_data['Team'].unique()
# Out:
# array(['Besiktas', 'Galatasaray', 'Fenerbahce', 'Trabzonspor',
#        'Sivasspor', 'Hatayspor', 'Alanyaspor', 'Fatih Karagumruk',
#        'Gaziantep FK', 'Goztepe', 'Konyaspor', 'Istanbul Basaksehir',
#        'Rizespor', 'Kasimpasa', 'Yeni Malatyaspor', 'Antalyaspor',
#        'Kayserispor', 'BB Erzurumspor', 'Ankaragucu', 'Genclerbirligi',
#        'Denizlispor'], dtype=object)

# %% [markdown]
# Merging Dataset

# %%
# Merge the teams_data with rank_outcomes_data based on the Team column
merged_data = pd.merge(teams_data, rank_outcomes_data, on='Team', how='inner')

# Display the merged data
merged_data.to_excel('merged_data.xlsx')

# %% [markdown]
# EDA

# %%
# Calculate summary statistics for the merged data
summary_statistics = merged_data.describe()

# Display the summary statistics
summary_statistics
# Out:
#        Total Distance Covered  Distance Covered Speed 0-0.2 m/s  \
# count            7.140000e+02                        714.000000
# mean             2.110883e+05                        676.494403
# std              5.937351e+05                       1907.528424
# min              6.725400e+04                        213.000000
# 25%              1.078530e+05                        315.000000
# 50%              1.107100e+05                        353.000000
# 75%              1.138085e+05                        395.000000
# max              4.363707e+06                      15187.000000
#
#        Distance Covered Speed 0.21-2 m/s  Distance Covered Speed 2.01-4 m/s  \
# count                       7.140000e+02                       7.140000e+02
# mean                        7.899174e+04                       8.003605e+04
# std                         2.221861e+05                       2.254397e+05
# min                         2.485700e+04                       2.606500e+04
# ...

# %%
# Select relevant columns for correlation analysis
correlation_columns = [
    'Total Distance Covered', 'Distance Covered Speed 0-0.2 m/s', 
    'Distance Covered Speed 0.21-2 m/s', 'Distance Covered Speed 2.01-4 m/s', 
    'Distance Covered Speed 4.01-5.5 m/s', 'Distance Covered Speed 5.51-7 m/s', 
    'Distance Covered Speed >7 m/s', 'No. of Accelerations 5.5-7 m/s²', 
    'No. of Accelerations >7 m/s²', 'Maximal Speed', 
    'Goals Scored', 'Goals Conceded', 'Points'
]

# Calculate the correlation matrix
correlation_matrix = merged_data[correlation_columns].corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                                      Total Distance Covered  \
# Total Distance Covered                             1.000000
# Distance Covered Speed 0-0.2 m/s                   0.996896
# Distance Covered Speed 0.21-2 m/s                  0.999504
# Distance Covered Speed 2.01-4 m/s                  0.999752
# Distance Covered Speed 4.01-5.5 m/s                0.999384
# Distance Covered Speed 5.51-7 m/s                  0.998596
# Distance Covered Speed >7 m/s                      0.996658
# No. of Accelerations 5.5-7 m/s²                    0.998542
# No. of Accelerations >7 m/s²                       0.997186
# Maximal Speed                                      0.999758
# Goals Scored                                       0.001021
# Goals Conceded                                    -0.003334
# Points                                             0.002214
#
#                                      Distance Covered Speed 0-0.2 m/s  \
# ...

# %%
team_appearance_counts = teams_data['Team'].value_counts().reset_index()
team_appearance_counts.columns = ['Team', 'Appearances']
team_appearance_counts
# Out:
#                    Team  Appearances
# 0              Besiktas           42
# 1      Yeni Malatyaspor           42
# 2            Alanyaspor           41
# 3             Kasimpasa           40
# 4           Antalyaspor           40
# 5           Galatasaray           40
# 6           Trabzonspor           40
# 7        BB Erzurumspor           40
# 8             Konyaspor           39
# 9          Gaziantep FK           39
# 10           Fenerbahce           39
# 11          Kayserispor           37
# 12           Ankaragucu           29
# 13  Istanbul Basaksehir           27
# 14     Fatih Karagumruk           26
# 15              Goztepe           26
# 16            Hatayspor           26
# 17             Rizespor           26
# 18            Sivasspor           25
# 19       Genclerbirligi           25
# 20          Denizlispor           25

# %% [markdown]
# For some teams we don't have info regarding each match
